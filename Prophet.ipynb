# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('FAANG.csv')

# %%
print(df.head())
# Out:
#                   date  open_aapl  close_aapl   open_amzn  close_amzn  \
# 0  2012-05-18 00:00:00  76.279999   75.768570  219.410004  213.850006
# 1  2012-05-21 00:00:00  76.357140   80.182854  214.029999  218.110001
# 2  2012-05-22 00:00:00  81.364288   79.567146  218.309998  215.330002
# 3  2012-05-23 00:00:00  79.642860   81.508568  214.710007  217.279999
# 4  2012-05-24 00:00:00  82.267143   80.760002  216.979996  215.240005
#
#      open_fb   close_fb  open_googl  close_googl  open_nflx  close_nflx
# 0  42.049999  38.230000  312.862854   300.500488  10.328571    9.994286
# 1  36.529999  34.029999  300.555542   307.362366   9.978572   10.248571
# 2  32.610001  31.000000  307.027039   300.700714  10.257143    9.672857
# 3  31.370001  32.000000  301.126129   305.035034   9.638572   10.272857
# 4  32.950001  33.029999  304.884888   302.132141  10.217143   10.038571

# %%
print(df.shape)
# Out:
# (1924, 11)

# %%
df['date'] = pd.to_datetime(df.date,format='%Y-%m-%d')
df.index = df['date']

# %%
train = new_data[:987]
valid = new_data[987:]

# %%
print(train.shape)
# Out:
# (987, 2)

# %%
print(valid.shape)
# Out:
# (937, 2)

# %%
from fbprophet import Prophet

# %%
new_data = pd.DataFrame(index=range(0,len(df)),columns=['date', 'close_aapl'])

# %%
for i in range(0,len(data)):
     new_data['date'][i] = data['date'][i]
     new_data['close_aapl'][i] = data['close_aapl'][i]

# %%
new_data['date'] = pd.to_datetime(new_data.date,format='%Y-%m-%d')
new_data.index = new_data['date']

# %%
new_data.rename(columns={'close_aapl': 'y', 'date': 'ds'}, inplace=True)

# %%
train = new_data[:987]
valid = new_data[987:]

# %%
model = Prophet()
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
close_prices = model.make_future_dataframe(periods=len(valid))
forecast = model.predict(close_prices)

# %%
forecast_valid = forecast['yhat'][987:]
rms=np.sqrt(np.mean(np.power((np.array(valid['y'])-np.array(forecast_valid)),2)))
rms
# Out:
# 154.06647911854998

# %%
valid['Predictions'] = 0
valid['Predictions'] = forecast_valid.values

plt.figure(figsize=(16,8))
plt.plot(train['y'])
plt.plot(valid[['y', 'Predictions']])
plt.title('Apple Stock')A
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0, 0.5, 'Price')

# %%
new_data = pd.DataFrame(index=range(0,len(df)),columns=['date', 'close_amzn'])
for i in range(0,len(data)):
     new_data['date'][i] = data['date'][i]
     new_data['close_amzn'][i] = data['close_amzn'][i]

# %%
new_data['date'] = pd.to_datetime(new_data.date,format='%Y-%m-%d')
new_data.index = new_data['date']

# %%
new_data.rename(columns={'close_amzn': 'y', 'date': 'ds'}, inplace=True)

# %%
train = new_data[:987]
valid = new_data[987:]

# %%
model = Prophet()
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
close_prices = model.make_future_dataframe(periods=len(valid))
forecast = model.predict(close_prices)

# %%
forecast_valid = forecast['yhat'][987:]
rms=np.sqrt(np.mean(np.power((np.array(valid['y'])-np.array(forecast_valid)),2)))
rms
# Out:
# 624.2051051137631

# %%
valid['Predictions'] = 0
valid['Predictions'] = forecast_valid.values

plt.figure(figsize=(16,8))
plt.plot(train['y'])
plt.plot(valid[['y', 'Predictions']])
plt.title('Amazon Stock')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0, 0.5, 'Price')

# %%
new_data = pd.DataFrame(index=range(0,len(df)),columns=['date', 'close_fb'])
for i in range(0,len(data)):
     new_data['date'][i] = data['date'][i]
     new_data['close_fb'][i] = data['close_fb'][i]
new_data['date'] = pd.to_datetime(new_data.date,format='%Y-%m-%d')
new_data.index = new_data['date']
new_data.rename(columns={'close_fb': 'y', 'date': 'ds'}, inplace=True)

train = new_data[:987]
valid = new_data[987:]

model = Prophet()
model.fit(train)

close_prices = model.make_future_dataframe(periods=len(valid))
forecast = model.predict(close_prices)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_valid = forecast['yhat'][987:]
rms=np.sqrt(np.mean(np.power((np.array(valid['y'])-np.array(forecast_valid)),2)))
rms
# Out:
# 21.96472158522517

# %%
valid['Predictions'] = 0
valid['Predictions'] = forecast_valid.values

plt.figure(figsize=(16,8))
plt.plot(train['y'])
plt.plot(valid[['y', 'Predictions']])
plt.title('Facebook Stock')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0, 0.5, 'Price')

# %%
new_data = pd.DataFrame(index=range(0,len(df)),columns=['date', 'close_googl'])
for i in range(0,len(data)):
     new_data['date'][i] = data['date'][i]
     new_data['close_googl'][i] = data['close_googl'][i]
new_data['date'] = pd.to_datetime(new_data.date,format='%Y-%m-%d')
new_data.index = new_data['date']
new_data.rename(columns={'close_googl': 'y', 'date': 'ds'}, inplace=True)

train = new_data[:987]
valid = new_data[987:]

model = Prophet()
model.fit(train)

close_prices = model.make_future_dataframe(periods=len(valid))
forecast = model.predict(close_prices)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_valid = forecast['yhat'][987:]
rms=np.sqrt(np.mean(np.power((np.array(valid['y'])-np.array(forecast_valid)),2)))
rms
# Out:
# 73.4873628293763

# %%
valid['Predictions'] = 0
valid['Predictions'] = forecast_valid.values

plt.figure(figsize=(16,8))
plt.plot(train['y'])
plt.plot(valid[['y', 'Predictions']])
plt.title('Google Stock')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0, 0.5, 'Price')

# %%
new_data = pd.DataFrame(index=range(0,len(df)),columns=['date', 'close_nflx'])
for i in range(0,len(data)):
     new_data['date'][i] = data['date'][i]
     new_data['close_nflx'][i] = data['close_nflx'][i]
new_data['date'] = pd.to_datetime(new_data.date,format='%Y-%m-%d')
new_data.index = new_data['date']
new_data.rename(columns={'close_nflx': 'y', 'date': 'ds'}, inplace=True)

train = new_data[:987]
valid = new_data[987:]

model = Prophet()
model.fit(train)

close_prices = model.make_future_dataframe(periods=len(valid))
forecast = model.predict(close_prices)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_valid = forecast['yhat'][987:]
rms=np.sqrt(np.mean(np.power((np.array(valid['y'])-np.array(forecast_valid)),2)))
rms
# Out:
# 154.06647911854998

# %%
valid['Predictions'] = 0
valid['Predictions'] = forecast_valid.values

plt.figure(figsize=(16,8))
plt.plot(train['y'])
plt.plot(valid[['y', 'Predictions']])
plt.title('Netflix')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0, 0.5, 'Price')
