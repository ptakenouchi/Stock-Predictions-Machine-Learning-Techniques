# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import yfinance as yf

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
data_aapl = yf.download("AAPL", start="2010-01-01", end="2020-01-10").reset_index()
data_aapl_pdr = pdr.get_data_yahoo("AAPL", start="2010-01-01", end="2020-01-01").reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_aapl=data_aapl[['Date','Open','Low','High','Close','Volume']]
data_aapl.head()
# Out:
#         Date       Open        Low       High      Close     Volume
# 0 2010-01-04  30.490000  30.340000  30.642857  30.572857  123432400
# 1 2010-01-05  30.657143  30.464285  30.798571  30.625713  150476200
# 2 2010-01-06  30.625713  30.107143  30.747143  30.138571  138040000
# 3 2010-01-07  30.250000  29.864286  30.285715  30.082857  119282800
# 4 2010-01-08  30.042856  29.865715  30.285715  30.282858  111902700

# %%
data_aapl_pdr.head(-5)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-01-04   30.490000   30.642857   30.340000   30.572857   26.601469
# 1    2010-01-05   30.657143   30.798571   30.464285   30.625713   26.647457
# 2    2010-01-06   30.625713   30.747143   30.107143   30.138571   26.223597
# 3    2010-01-07   30.250000   30.285715   29.864286   30.082857   26.175119
# 4    2010-01-08   30.042856   30.285715   29.865715   30.282858   26.349140
# ...         ...         ...         ...         ...         ...         ...
# 2506 2019-12-17  279.570007  281.769989  278.799988  280.410004  280.410004
# 2507 2019-12-18  279.799988  281.899994  279.119995  279.739990  279.739990
# 2508 2019-12-19  279.500000  281.179993  278.950012  280.019989  280.019989
# 2509 2019-12-20  282.230011  282.649994  278.559998  279.440002  279.440002
# 2510 2019-12-23  280.529999  284.250000  280.369995  284.000000  284.000000
#
#          Volume
# 0     123432400
# 1     150476200
# ...

# %%
data_fb = yf.download("FB", start="2010-01-01", end="2020-01-10").reset_index()
data_fb_pdr = pdr.get_data_yahoo("FB", start="2010-01-01", end="2020-01-01").reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_fb=data_fb[['Date','Open','Low','High','Close','Volume']]
data_fb.head()
# Out:
#         Date       Open        Low       High      Close     Volume
# 0 2012-05-18  42.049999  38.000000  45.000000  38.230000  573576400
# 1 2012-05-21  36.529999  33.000000  36.660000  34.029999  168192700
# 2 2012-05-22  32.610001  30.940001  33.590000  31.000000  101786600
# 3 2012-05-23  31.370001  31.360001  32.500000  32.000000   73600000
# 4 2012-05-24  32.950001  31.770000  33.209999  33.029999   50237200

# %%
data_fb_pdr.head(-5)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1    2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2    2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3    2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4    2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...         ...         ...         ...         ...         ...         ...
# 1907 2019-12-17  198.839996  199.000000  196.130005  198.389999  198.389999
# 1908 2019-12-18  200.089996  204.300003  200.089996  202.500000  202.500000
# 1909 2019-12-19  202.779999  206.300003  202.509995  206.059998  206.059998
# 1910 2019-12-20  207.479996  207.710007  203.429993  206.300003  206.300003
# 1911 2019-12-23  206.699997  208.589996  205.679993  206.179993  206.179993
#
#          Volume
# 0     573576400
# 1     168192700
# ...

# %%
data_amzn = yf.download("AMZN", start="2010-01-01", end="2020-01-10").reset_index()
data_amzn_pdr = pdr.get_data_yahoo("AMZN", start="2010-01-01", end="2020-01-01").reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_amzn=data_amzn[['Date','Open','Low','High','Close','Volume']]
data_amzn.head()
# Out:
#         Date        Open         Low        High       Close    Volume
# 0 2010-01-04  136.250000  133.139999  136.610001  133.899994   7599900
# 1 2010-01-05  133.429993  131.809998  135.479996  134.690002   8851900
# 2 2010-01-06  134.600006  131.649994  134.729996  132.250000   7178800
# 3 2010-01-07  132.009995  128.800003  132.320007  130.000000  11030200
# 4 2010-01-08  130.559998  129.029999  133.679993  133.520004   9830500

# %%
data_amzn_pdr.head(-5)
# Out:
#            Date         Open         High          Low        Close  \
# 0    2010-01-04   136.250000   136.610001   133.139999   133.899994
# 1    2010-01-05   133.429993   135.479996   131.809998   134.690002
# 2    2010-01-06   134.600006   134.729996   131.649994   132.250000
# 3    2010-01-07   132.009995   132.320007   128.800003   130.000000
# 4    2010-01-08   130.559998   133.679993   129.029999   133.520004
# ...         ...          ...          ...          ...          ...
# 2506 2019-12-17  1778.010010  1792.000000  1777.390015  1790.660034
# 2507 2019-12-18  1795.020020  1798.199951  1782.359985  1784.030029
# 2508 2019-12-19  1780.500000  1792.989990  1774.060059  1792.280029
# 2509 2019-12-20  1799.619995  1802.969971  1782.449951  1786.500000
# 2510 2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000
#
#         Adj Close    Volume
# 0      133.899994   7599900
# 1      134.690002   8851900
# 2      132.250000   7178800
# 3      130.000000  11030200
# ...

# %%
data_nflx = yf.download("NFLX", start="2010-01-01", end="2020-01-10").reset_index()
data_nflx_pdr = pdr.get_data_yahoo("NFLX", start="2010-01-01", end="2020-01-01").reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_nflx=data_nflx[['Date','Open','Low','High','Close','Volume']]
data_nflx.head()
# Out:
#         Date      Open       Low      High     Close    Volume
# 0 2010-01-04  7.931428  7.565714  7.961429  7.640000  17239600
# 1 2010-01-05  7.652857  7.258572  7.657143  7.358572  23753100
# 2 2010-01-06  7.361429  7.197143  7.672857  7.617143  23290400
# 3 2010-01-07  7.731429  7.462857  7.757143  7.485714   9955400
# 4 2010-01-08  7.498571  7.465714  7.742857  7.614286   8180900

# %%
data_nflx_pdr.head(-5)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-01-04    7.931428    7.961429    7.565714    7.640000    7.640000
# 1    2010-01-05    7.652857    7.657143    7.258572    7.358572    7.358572
# 2    2010-01-06    7.361429    7.672857    7.197143    7.617143    7.617143
# 3    2010-01-07    7.731429    7.757143    7.462857    7.485714    7.485714
# 4    2010-01-08    7.498571    7.742857    7.465714    7.614286    7.614286
# ...         ...         ...         ...         ...         ...         ...
# 2506 2019-12-17  307.359985  316.799988  306.600006  315.480011  315.480011
# 2507 2019-12-18  316.260010  325.359985  315.600006  320.799988  320.799988
# 2508 2019-12-19  324.500000  332.829987  324.179993  332.220001  332.220001
# 2509 2019-12-20  335.000000  338.000000  330.600006  336.899994  336.899994
# 2510 2019-12-23  337.760010  337.950012  331.019989  333.100006  333.100006
#
#         Volume
# 0     17239600
# 1     23753100
# ...

# %%
data_googl = yf.download("GOOGL", start="2010-01-01", end="2020-01-10").reset_index()
data_googl_pdr = pdr.get_data_yahoo("GOOGL", start="2010-01-01", end="2020-01-01").reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_googl=data_googl[['Date','Open','Low','High','Close','Volume']]
data_googl.head()
# Out:
#         Date        Open         Low        High       Close    Volume
# 0 2010-01-04  313.788788  312.432434  315.070068  313.688690   3908400
# 1 2010-01-05  313.903900  311.081085  314.234222  312.307312   6003300
# 2 2010-01-06  313.243256  303.483490  313.243256  304.434448   7949400
# 3 2010-01-07  305.005005  296.621613  305.305298  297.347351  12815700
# 4 2010-01-08  296.296295  294.849854  301.926941  301.311310   9439100

# %%
data_googl_pdr.head(-5)
# Out:
#            Date         Open         High          Low        Close  \
# 0    2010-01-04   313.788788   315.070068   312.432434   313.688690
# 1    2010-01-05   313.903900   314.234222   311.081085   312.307312
# 2    2010-01-06   313.243256   313.243256   303.483490   304.434448
# 3    2010-01-07   305.005005   305.305298   296.621613   297.347351
# 4    2010-01-08   296.296295   301.926941   294.849854   301.311310
# ...         ...          ...          ...          ...          ...
# 2506 2019-12-17  1362.410034  1364.329956  1350.770020  1354.890015
# 2507 2019-12-18  1357.000000  1359.430054  1350.459961  1351.910034
# 2508 2019-12-19  1351.910034  1357.530029  1348.750000  1356.439941
# 2509 2019-12-20  1363.099976  1364.000000  1350.729980  1351.219971
# 2510 2019-12-23  1358.729980  1361.849976  1348.000000  1350.630005
#
#         Adj Close    Volume
# 0      313.688690   3908400
# 1      312.307312   6003300
# 2      304.434448   7949400
# 3      297.347351  12815700
# ...

# %%
from functools import reduce

faang_dataframes = [data_aapl,data_amzn,data_fb,data_googl,data_nflx]

faang_data = reduce(lambda left,right: pd.merge(left,right,on='Date'), faang_dataframes)

faang_data.head()
# Out:
#         Date     Open_x      Low_x     High_x    Close_x   Volume_x  \
# 0 2012-05-18  76.279999  74.597145  77.629997  75.768570  183073100
# 1 2012-05-21  76.357140  76.292854  80.220001  80.182854  157776500
# 2 2012-05-22  81.364288  78.940002  81.982857  79.567146  173717600
# 3 2012-05-23  79.642860  79.032860  81.828575  81.508568  146224400
# 4 2012-05-24  82.267143  80.175713  82.357140  80.760002  124057500
#
#        Open_y       Low_y      High_y     Close_y  ...      Open_y  \
# 0  219.410004  212.809998  219.630005  213.850006  ...  312.862854
# 1  214.029999  212.820007  219.979996  218.110001  ...  300.555542
# 2  218.309998  213.960007  218.869995  215.330002  ...  307.027039
# 3  214.710007  211.179993  217.550003  217.279999  ...  301.126129
# 4  216.979996  212.699997  217.660004  215.240005  ...  304.884888
#
#         Low_y      High_y     Close_y  Volume_y       Open       Low  \
# 0  298.648651  316.526520  300.500488  11935000  10.328571  9.337143
# ...

# %%
faang_data.columns = ['date','open_aapl','high_aapl','low_aapl','close_aapl','volume_aapl','open_amzn',
                      'high_amzn','low_amzn','close_amzn','volume_amzn','open_fb','high_fb','low_fb','close_fb',
                      'volume_fb','open_googl','high_googl','low_googl','close_googl','volume_googl','open_nflx',
                      'high_nflx','low_nflx','close_nflx','volume_nflx']

pd.options.display.max_columns = None
display(faang_data)
# Out:
#            date   open_aapl   high_aapl    low_aapl  close_aapl  volume_aapl  \
# 0    2012-05-18   76.279999   74.597145   77.629997   75.768570    183073100
# 1    2012-05-21   76.357140   76.292854   80.220001   80.182854    157776500
# 2    2012-05-22   81.364288   78.940002   81.982857   79.567146    173717600
# 3    2012-05-23   79.642860   79.032860   81.828575   81.508568    146224400
# 4    2012-05-24   82.267143   80.175713   82.357140   80.760002    124057500
# ...         ...         ...         ...         ...         ...          ...
# 1919 2020-01-06  293.790009  292.750000  299.959991  299.799988     29596800
# 1920 2020-01-07  299.839996  297.480011  300.899994  298.390015     27218000
# 1921 2020-01-08  297.160004  297.160004  304.440002  303.190002     33019800
# 1922 2020-01-09  307.239990  306.200012  310.429993  309.630005     42527100
# 1923 2020-01-10  310.600006  308.250000  312.670013  310.329987     35161200
#
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
rds_connection_string = "gtcxzgvpwnihgv:53b845152632e1d5d7549d73bdea57d2b4be83f682a05cec298eb551d072a301@ec2-174-129-33-201.compute-1.amazonaws.com/d4e3lm8nf8o54g"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['faang_data']

# %%
faang_data.to_sql(name='faang_data', con=engine, if_exists='replace', index=False)
pd.read_sql_query('select * from faang_data', con=engine).head()
# Out:
#         date  open_aapl  high_aapl   low_aapl  close_aapl  volume_aapl  \
# 0 2012-05-18  76.279999  74.597145  77.629997   75.768570    183073100
# 1 2012-05-21  76.357140  76.292854  80.220001   80.182854    157776500
# 2 2012-05-22  81.364288  78.940002  81.982857   79.567146    173717600
# 3 2012-05-23  79.642860  79.032860  81.828575   81.508568    146224400
# 4 2012-05-24  82.267143  80.175713  82.357140   80.760002    124057500
#
#     open_amzn   high_amzn    low_amzn  close_amzn  ...  open_googl  \
# 0  219.410004  212.809998  219.630005  213.850006  ...  312.862854
# 1  214.029999  212.820007  219.979996  218.110001  ...  300.555542
# 2  218.309998  213.960007  218.869995  215.330002  ...  307.027039
# 3  214.710007  211.179993  217.550003  217.279999  ...  301.126129
# 4  216.979996  212.699997  217.660004  215.240005  ...  304.884888
#
#    high_googl   low_googl  close_googl  volume_googl  open_nflx  high_nflx  \
# ...

# %%
# data_aapl.to_sql(name='data_aapl', con=engine, if_exists='replace', index=False)
# pd.read_sql_query('select * from data_aapl', con=engine).head()

# %%
# data_amzn.to_sql(name='data_amzn', con=engine, if_exists='replace', index=False)
# pd.read_sql_query('select * from data_amzn', con=engine).head()

# %%
# data_nflx.to_sql(name='data_nflx', con=engine, if_exists='replace', index=False)
# pd.read_sql_query('select * from data_nflx', con=engine).head()

# %%
# data_googl.to_sql(name='data_googl', con=engine, if_exists='replace', index=False)
# pd.read_sql_query('select * from data_googl', con=engine).head()

# %%
# len(data_aapl)+len(data_amzn)+len(data_fb)+len(data_nflx)+len(data_googl)

# %%
# data_aapl[-20:]
